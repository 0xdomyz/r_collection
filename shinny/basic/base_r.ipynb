# %%
# Set up
set.seed(122)
histdata <- rnorm(500)

# %%
# input
num_observations <- 50

# %%
# process & results
data <- histdata[seq_len(num_observations)]
hist(data)
# Out:
# Plot with title "Histogram of data"
